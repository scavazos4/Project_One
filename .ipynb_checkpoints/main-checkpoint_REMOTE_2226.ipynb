# %%
# Dependencies

import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

from pprint import pprint

import numpy as np
import seaborn as sns
import csv
import gmaps

# %%
data = pd.read_csv("data.csv")

data.head()
# Out:
#                 street        city    zip state  beds  baths  sq_ft  \
# 0     1 KENNELFORD CIR  SACRAMENTO  95823    CA     3      2   1144
# 1       10 SEA FOAM CT  SACRAMENTO  95831    CA     3      3   2052
# 2       100 CHELSEA CT      FOLSOM  95630    CA     3      2   1905
# 3  100 CRYSTALWOOD CIR     LINCOLN  95648    CA     0      0      0
# 4  100 CRYSTALWOOD WAY     LINCOLN  95648    CA     0      0      0
#
#           type   price   latitude   longitude  day month  date  year
# 0  Residential  200345  38.464520 -121.427606  Mon   May    19  2008
# 1  Residential  415000  38.487885 -121.545947  Wed   May    21  2008
# 2  Residential  500000  38.694350 -121.177259  Mon   May    19  2008
# 3  Residential    4897  38.886091 -121.289744  Mon   May    19  2008
# 4  Residential    4897  38.886282 -121.289706  Mon   May    19  2008

# %%
#cleaning data
#removing houses with 0 rooms
cleanData = data[data.beds != 0]
cleanData = cleanData[cleanData.sq_ft != 0]

# %%
#price per sq_ft calculation and addition of df
cleanData["price/sq_ft"] = cleanData["price"]/cleanData["sq_ft"]

# %%
#running early plot on sq_ft by price
slope, intercept, r_value, p_value, std_err = stats.linregress(cleanData['sq_ft'],cleanData['price'])

ax = sns.regplot(x="sq_ft", y = "price", data=cleanData, color="g", \
                  line_kws={'label':"y = {0:.2f}x+{1:.1f}".format(slope,intercept)})
ax.legend()
ax.set(title="price vs sq ft")
plt.show


print(f"r = {r_value}")


# strong correlation of price and sq_ft of purhcases
# r = 0.72
# most common purchase size between 1000-2000 sq ft
# price between 85,000-400,000
# Out:
# r = 0.7319031190336979

# %%
medianSQFT = cleanData["sq_ft"].median()
medianPrice = cleanData["price"].median()
medianPricePerSQFT = cleanData["price/sq_ft"].median()

print(f"{medianSQFT} sq ft" )
print(f"$ {medianPrice}")
print(f"{medianPricePerSQFT} price/sqft")
# Out:
# 1418.5 sq ft
# $ 207986.5
# 137.11630485527544 price/sqft

# %%
#create bins to show price occurances
priceBins = [0,100000,200000,300000,400000,500000,900000]
priceGroupNames = ["<$100k","100k-200k","200k-300k",\
                  "300k-400k","400k-500k",">$500k"]

cleanData["Price Bins"] = pd.cut(cleanData["price"], priceBins, labels = priceGroupNames, include_lowest=True)

count, ax0 = plt.subplots(figsize = (15,8))
ax0 = sns.countplot(x = "Price Bins", data = cleanData).set_title("Purchases per Price", size = 30) 

ax0 =plt.xlabel("Price", size=20)
ax0 =plt.ylabel("Count", size=20)
ax0 =plt.xticks(fontsize= 14)
ax0 =plt.yticks(fontsize= 14)
# purchase price would likely correlate with median income of the city. 
# most purchases occuring between 100k-300k price range

# %%
#create bins to show sq ft occurances

sqftBins = [0,1000,1500,2000,2500,3000,5000]
sqftGroupNames = ["<1000","1000-1500","1500-2000","2000-2500","2500-3000",">3000"]

cleanData["sqft Bins"] = pd.cut(cleanData["sq_ft"], sqftBins, labels=sqftGroupNames, include_lowest=True)

count, ax1 = plt.subplots(figsize = (15,8))
ax1 = sns.countplot(x = "sqft Bins", data = cleanData).set_title("Purchases per Sq Ft", size = 30) 

ax1 =plt.xlabel("Sq Ft", size=20)
ax1 =plt.ylabel("Count", size=20)
ax1 =plt.xticks(fontsize= 14)
ax1 =plt.yticks(fontsize= 14)
#skew right data set for the amount of homes purchased per sq ft
# most common size house is 1000-1500 sq ft

# %%
#removing occurance zip codes less than 20
cleanDataBox = cleanData.groupby("zip")
cleanDataBox = cleanDataBox.filter(lambda x: len(x) > 12)

# %%
cleanDataBoxZip = cleanDataBox.groupby(["zip"])


cleanDataBoxZip = cleanDataBoxZip.median()

cleanDataBoxZip = cleanDataBoxZip.drop(["latitude","longitude","date", "year"], axis =1)
cleanDataBoxZip

# 1418.5 sq ft
# $ 207986.5
# 137.11630485527544 price/sqft
# Out:
#        beds  baths   sq_ft     price  price/sq_ft
# zip
# 95608   3.0    2.0  1472.5  248567.0   182.404747
# 95621   3.0    2.0  1267.5  168646.5   143.117290
# 95624   4.0    2.0  1721.0  229000.0   138.913624
# 95630   4.0    2.0  2185.0  441000.0   178.073707
# 95632   3.0    2.0  1513.5  214673.5   137.476714
# 95660   3.0    2.0  1152.0  129000.0   116.533139
# 95670   3.0    2.0  1486.0  233848.5   153.068279
# 95678   3.0    2.0  1628.0  233750.0   162.218337
# 95757   4.0    3.0  2658.0  335750.0   140.167315
# 95758   3.0    2.0  1595.5  220500.0   138.561416
# 95815   2.5    1.0  1021.5   93070.0    85.303918
# 95820   2.5    1.0  1028.5  122587.5   114.669207
# 95822   3.0    2.0  1142.0  128375.0   112.053571
# 95823   3.0    2.0  1436.0  168000.0   116.577221
# 95826   3.0    2.0  1240.0  180500.0   148.399089
# 95828   3.0    2.0  1448.0  170000.0   109.970674
# 95833   3.0    2.0  1390.0  174250.0   129.629630
# 95834   3.0    2.0  1601.0  232500.0   134.624251
# ...

# %%
#box plot, price per zip code

ax2 = plt.subplots(figsize = (15,8))
ax2 = sns.boxplot(x="zip", y ="price", data = cleanDataBox).set_title("Average Price per Zipcode", size = 30)

ax2 =plt.xlabel("Zipcode", size=20)
ax2 =plt.ylabel("Price", size=20)
ax2 =plt.xticks(fontsize= 11)
ax2 =plt.yticks(fontsize= 15)

# 95630 zip code has the highest average purchase price
# 95815 zipcode has the lowest average purchase price

# %%
#box plot, zip code and sq feet

ax3 = plt.subplots(figsize = (15,8))
ax3 = sns.boxplot(x="zip", y ="sq_ft", data = cleanDataBox).set_title("Average Sq Ft per Zipcode", size = 30)

ax3 =plt.xlabel("Zipcode", size=20)
ax3 =plt.ylabel("Sq Ft", size=20)
ax3 =plt.xticks(fontsize= 11)
ax3 =plt.yticks(fontsize= 15)

# largest houses are in the 95757 zipcode
# smallest houses are in the 95815 zipcode (also lowest average price)

# %%
#box plot, zip code and price/sq feet

ax4 = plt.subplots(figsize = (15,8))
ax4 = sns.boxplot(x="zip", y ="price/sq_ft", data = cleanDataBox).set_title("Average Price/Sq Ft per Zipcode", size = 30)

ax4 =plt.xlabel("Zipcode", size=20)
ax4 =plt.ylabel("Price/Sq Ft", size=20)
ax4 =plt.xticks(fontsize= 11)
ax4 =plt.yticks(fontsize= 15)

# 95608 has largest aver price/sqft
# 95815 has smallest aver price /sqft

# %%
# purchases per day
countplt,ax5 = plt.subplots(figsize = (10,7))
ax5 = sns.countplot(x = "day", data = cleanData).set_title("Purchases per Day", size = 30)

ax5 =plt.xlabel("Day", size=20)
ax5 =plt.ylabel("Count", size=20)
ax5 =plt.xticks(fontsize= 15)
ax5 =plt.yticks(fontsize= 15)

# Monday and Friday are most common to purchase a house

# %%
#purchases per zip code
count, ax6 = plt.subplots(figsize = (18,8))
ax6 = sns.countplot(x = "zip", data = cleanDataBox).set_title("Purchases per Zipcode", size = 30) 

ax6 =plt.xlabel("ZipCode", size=20)
ax6 =plt.ylabel("Count", size=20)
ax6 =plt.xticks(fontsize= 12)
ax6 =plt.yticks(fontsize= 15)

# 95823 has most purchases, does it ahve the most average data.

# %%
count, ax7 = plt.subplots(figsize = (15,8))
ax7 = sns.countplot(x = "beds", data = cleanData).set_title("Bedroom Count", size = 30)

ax7 =plt.xlabel("Bedrooms", size=20)
ax7 =plt.ylabel("Count", size=20)
ax7 =plt.xticks(fontsize= 15)
ax7 =plt.yticks(fontsize= 15)

#most common bedroom count is 3 bedrooms

# %%
# Plot Heatmap for Price
fig = gmaps.figure()

locations = cleanData[["latitude", "longitude"]]
price = cleanData["price"]

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights = price,
                                 dissipating=False, max_intensity=800000,
                                 point_radius=0.01)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot Heatmap for Price
fig = gmaps.figure()

locations = cleanData[["latitude", "longitude"]]
pricesq_ft = cleanData["price/sq_ft"]

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights = pricesq_ft,
                                 dissipating=False, max_intensity=450,
                                 point_radius=0.01)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
cleanData.head()
# Out:
#                street        city    zip state  beds  baths  sq_ft  \
# 0    1 KENNELFORD CIR  SACRAMENTO  95823    CA     3      2   1144
# 1      10 SEA FOAM CT  SACRAMENTO  95831    CA     3      3   2052
# 2      100 CHELSEA CT      FOLSOM  95630    CA     3      2   1905
# 5     100 REBECCA WAY      FOLSOM  95630    CA     3      2   2185
# 6  100 TOURMALINE CIR  SACRAMENTO  95834    CA     5      3   3076
#
#           type   price   latitude   longitude  day month  date  year  \
# 0  Residential  200345  38.464520 -121.427606  Mon   May    19  2008
# 1  Residential  415000  38.487885 -121.545947  Wed   May    21  2008
# 2  Residential  500000  38.694350 -121.177259  Mon   May    19  2008
# 5  Residential  344250  38.684790 -121.149199  Wed   May    21  2008
# 6  Residential  240000  38.634370 -121.510779  Mon   May    19  2008
#
#    price/sq_ft Price Bins  sqft Bins
# 0   175.126748  200k-300k  1000-1500
# 1   202.241715  400k-500k  2000-2500
# ...

# %%
# Plot Heatmap for Price
fig = gmaps.figure()

locations = cleanData[["latitude", "longitude"]]
#pricesq_ft = cleanData["price/sq_ft"]

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations,
                                 dissipating=False, max_intensity=4,
                                 point_radius=0.008)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#std calculations
medianSQFT = cleanDataBoxZip["sq_ft"].median()
medianPrice = cleanDataBoxZip["price"].median()
medianPricePerSQFT = cleanDataBoxZip["price/sq_ft"].median()

stdvPrice = cleanDataBoxZip["price"].std()
stdvSQFT = cleanDataBoxZip["sq_ft"].std()
stdvPriceSQFT = cleanDataBoxZip["price/sq_ft"].std()



stdvDFPrice=cleanDataBoxZip[(cleanDataBoxZip["price"] > medianPrice-stdvPrice*.25) & (cleanDataBoxZip["price"] < medianPrice+stdvPrice*.25)]
stdvDFsqft=stdvDFPrice[(stdvDFPrice["sq_ft"] > medianSQFT-stdvSQFT*.25) & (stdvDFPrice["sq_ft"] < medianSQFT+stdvSQFT*.25)]
stdvDFPricesqft=stdvDFsqft[(stdvDFsqft["price/sq_ft"] > medianPricePerSQFT-stdvPriceSQFT*.25) & (stdvDFsqft["price/sq_ft"] < medianPricePerSQFT+stdvPriceSQFT*.25)]


stdvDFPricesqft
# Out:
#        beds  baths   sq_ft     price  price/sq_ft
# zip
# 95632   3.0    2.0  1513.5  214673.5   137.476714

# %%
# Plot Heatmap for Price
fig = gmaps.figure()

avgZip = cleanDataBox.loc[cleanDataBox["zip"]== 95632]
locations = avgZip[["latitude", "longitude"]]


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations,
                                 dissipating=False, max_intensity=1,
                                 point_radius=0.0025)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
